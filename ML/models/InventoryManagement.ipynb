# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/docs/examples/index_structs/struct_indices/SQLIndexDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text-to-SQL Guide (Query Engine + Retriever)
#
# This is a basic guide to LlamaIndex's Text-to-SQL capabilities.
# 1. We first show how to perform text-to-SQL over a toy dataset: this will do "retrieval" (sql query over db) and "synthesis".
#
# 2. We finally show you how to define a text-to-SQL retriever on its own.
#
# **NOTE:** Any Text-to-SQL application should be aware that executing
# arbitrary SQL queries can be a security risk. It is recommended to
# take precautions as needed, such as using restricted roles, read-only
# databases, sandboxing, etc.

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# %pip install llama-index==0.10.18 llama-index-llms-groq==0.1.3 groq==0.4.2 llama-index-embeddings-huggingface==0.2.0
# Out:
# Collecting llama-index==0.10.18
#   Downloading llama_index-0.10.18-py3-none-any.whl.metadata (8.8 kB)
# Collecting llama-index-llms-groq==0.1.3
#   Downloading llama_index_llms_groq-0.1.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting groq==0.4.2
#   Downloading groq-0.4.2-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-embeddings-huggingface==0.2.0
#   Downloading llama_index_embeddings_huggingface-0.2.0-py3-none-any.whl.metadata (725 bytes)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama-index==0.10.18)
#   Downloading llama_index_agent_openai-0.1.7-py3-none-any.whl.metadata (644 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index==0.10.18)
#   Downloading llama_index_cli-0.1.13-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.11.0,>=0.10.18 (from llama-index==0.10.18)
#   Downloading llama_index_core-0.10.68.post1-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index==0.10.18)
#   Downloading llama_index_embeddings_openai-0.1.11-py3-none-any.whl.metadata (655 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index==0.10.18)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index==0.10.18)
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama-index==0.10.18)
#   Downloading llama_index_llms_openai-0.1.31-py3-none-any.whl.metadata (650 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index==0.10.18)
#   Downloading llama_index_multi_modal_llms_openai-0.1.9-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index==0.10.18)
#   Downloading llama_index_program_openai-0.1.7-py3-none-any.whl.metadata (760 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index==0.10.18)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index==0.10.18)
#   Downloading llama_index_readers_file-0.1.33-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index==0.10.18)
#   Downloading llama_index_readers_llama_parse-0.1.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-llms-openai-like<0.2.0,>=0.1.3 (from llama-index-llms-groq==0.1.3)
#   Downloading llama_index_llms_openai_like-0.1.3-py3-none-any.whl.metadata (753 bytes)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq==0.4.2) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq==0.4.2) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from groq==0.4.2)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq==0.4.2) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq==0.4.2) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq==0.4.2) (4.12.2)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (0.24.7)
# Collecting sentence-transformers<3.0.0,>=2.6.1 (from llama-index-embeddings-huggingface==0.2.0)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq==0.4.2) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq==0.4.2) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq==0.4.2) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq==0.4.2)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq==0.4.2)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (4.66.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (3.10.10)
# Collecting minijinja>=1.0 (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0)
#   Downloading minijinja-2.2.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2.0.36)
# Collecting dataclasses-json (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (3.4.2)
# Requirement already satisfied: nltk!=3.9,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (10.4.0)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.16.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.19 (from llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2->llama-index==0.10.18)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl.metadata (760 bytes)
# Collecting openai>=1.1.0 (from llama-index-legacy<0.10.0,>=0.9.48->llama-index==0.10.18)
#   Downloading openai-1.52.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-openai-like<0.2.0,>=0.1.3->llama-index-llms-groq==0.1.3) (4.44.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.18) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.18)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.18)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index==0.10.18)
#   Downloading llama_parse-0.5.12-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq==0.4.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq==0.4.2) (2.23.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index==0.10.18) (2.6)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from llama-parse>=0.4.0->llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index==0.10.18) (8.1.7)
# INFO: pip is looking at multiple versions of llama-parse to determine which version is compatible with other requirements. This could take a while.
#   Downloading llama_parse-0.5.11-py3-none-any.whl.metadata (6.9 kB)
#   Downloading llama_parse-0.5.10-py3-none-any.whl.metadata (6.9 kB)
#   Downloading llama_parse-0.5.9-py3-none-any.whl.metadata (6.9 kB)
#   Downloading llama_parse-0.5.8-py3-none-any.whl.metadata (6.4 kB)
#   Downloading llama_parse-0.5.7-py3-none-any.whl.metadata (6.4 kB)
#   Downloading llama_parse-0.5.6-py3-none-any.whl.metadata (6.1 kB)
#   Downloading llama_parse-0.5.5-py3-none-any.whl.metadata (6.1 kB)
# INFO: pip is still looking at multiple versions of llama-parse to determine which version is compatible with other requirements. This could take a while.
#   Downloading llama_parse-0.5.4-py3-none-any.whl.metadata (6.1 kB)
#   Downloading llama_parse-0.5.3-py3-none-any.whl.metadata (4.5 kB)
#   Downloading llama_parse-0.5.2-py3-none-any.whl.metadata (4.5 kB)
#   Downloading llama_parse-0.5.1-py3-none-any.whl.metadata (4.5 kB)
#   Downloading llama_parse-0.5.0-py3-none-any.whl.metadata (4.4 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Downloading llama_parse-0.4.9-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2024.9.11)
# Collecting jiter<1,>=0.4.0 (from openai>=1.1.0->llama-index-legacy<0.10.0,>=0.9.48->llama-index==0.10.18)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (3.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.2.0,>=0.1.3->llama-index-llms-groq==0.1.3) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-llms-openai-like<0.2.0,>=0.1.3->llama-index-llms-groq==0.1.3) (0.19.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18)
#   Downloading marshmallow-3.23.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.18->llama-index==0.10.18) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface==0.2.0) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.1->llama-index-embeddings-huggingface==0.2.0) (3.0.2)
# Downloading llama_index-0.10.18-py3-none-any.whl (5.6 kB)
# Downloading llama_index_llms_groq-0.1.3-py3-none-any.whl (2.7 kB)
# Downloading groq-0.4.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 3.7 MB/s eta 0:00:00
# Downloading llama_index_embeddings_huggingface-0.2.0-py3-none-any.whl (7.1 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 8.3 MB/s eta 0:00:00
# Downloading llama_index_agent_openai-0.1.7-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.13-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.10.68.post1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.4 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.1.11-py3-none-any.whl (6.3 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl (6.7 kB)
# Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.4 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.1.31-py3-none-any.whl (12 kB)
# Downloading llama_index_llms_openai_like-0.1.3-py3-none-any.whl (3.0 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.9-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.1.7-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.33-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.1.6-py3-none-any.whl (2.5 kB)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 14.9 MB/s eta 0:00:00
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_parse-0.4.9-py3-none-any.whl (9.4 kB)
# Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.0 MB/s eta 0:00:00
# Downloading minijinja-2.2.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.9/861.9 kB 51.3 MB/s eta 0:00:00
# Downloading openai-1.52.2-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 28.6 MB/s eta 0:00:00
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 16.9 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 28.2 MB/s eta 0:00:00
# Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: striprtf, dirtyjson, tenacity, pypdf, mypy-extensions, minijinja, marshmallow, jiter, h11, typing-inspect, tiktoken, httpcore, httpx, dataclasses-json, openai, llamaindex-py-client, llama-index-core, groq, sentence-transformers, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-llms-openai-like, llama-index-embeddings-huggingface, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-llms-groq, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed dataclasses-json-0.6.7 dirtyjson-1.0.8 groq-0.4.2 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 llama-index-0.10.18 llama-index-agent-openai-0.1.7 llama-index-cli-0.1.13 llama-index-core-0.10.68.post1 llama-index-embeddings-huggingface-0.2.0 llama-index-embeddings-openai-0.1.11 llama-index-indices-managed-llama-cloud-0.1.6 llama-index-legacy-0.9.48.post3 llama-index-llms-groq-0.1.3 llama-index-llms-openai-0.1.31 llama-index-llms-openai-like-0.1.3 llama-index-multi-modal-llms-openai-0.1.9 llama-index-program-openai-0.1.7 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.33 llama-index-readers-llama-parse-0.1.6 llama-parse-0.4.9 llamaindex-py-client-0.1.19 marshmallow-3.23.0 minijinja-2.2.0 mypy-extensions-1.0.0 openai-1.52.2 pypdf-4.3.1 sentence-transformers-2.7.0 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.8.0 typing-inspect-0.9.0

# %%
from llama_index.core import (
    VectorStoreIndex
)
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.llms.groq import Groq
# import os
# from dotenv import load_dotenv
# load_dotenv()
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from IPython.display import Markdown, display

# %% [markdown]
# ### Create Database Schema
#
# We use `sqlalchemy`, a popular SQL database toolkit, to create an empty `city_stats` Table

# %%
from sqlalchemy import (
    create_engine,
    MetaData,
    Table,
    Column,
    String,
    Integer,
    select,
    Float
)

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float
import pandas as pd

# Step 1: Create an in-memory SQLite database
engine = create_engine("sqlite:///:memory:")
metadata_obj = MetaData()

# Step 2: Define the 'products' table
products_table = Table(
    'products',
    metadata_obj,
    Column('product', String),
    Column('category', String),
    Column('sub_category', String),
    Column('brand', String),
    Column('sale_price', Float),
    Column('market_price', Float),
    Column('type', String),
    Column('rating', Float),
    Column('description', String),
    Column('quantity', Integer)
)

# Step 3: Create the table in the database
metadata_obj.create_all(engine)

# Step 4: Read data from a CSV file into a DataFrame
# Assuming your CSV file is named 'products.csv'
df = pd.read_csv('df.csv')

# Step 5: Drop the 'index' column from the DataFrame if it exists
df = df.drop(columns=['index'], errors='ignore')

# Step 6: Insert the data into the 'products' table without including the DataFrame index
df.to_sql('products', con=engine, if_exists='append', index=False)

# Verify by querying the data (Optional)
with engine.connect() as conn:
    result = conn.execute(products_table.select())
    for row in result:
        print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('Gulab Jal - Premium Rose Water', 'Beauty & Hygiene', 'Health & Medicine', 'Sri Sri Tattva', 65.0, 65.0, 'Ayurveda', None, 'Feel fresh with every spray of Sri Sri Tattva Gulab Jal (Rose Water). Boosted with the richness of rose extract, Gulab Jal acts as a natural skin ton ... (322 characters truncated) ...  Gulab\xa0Jal is\xa0a very good toner for skin, which helps in tightening the skin.Refreshing: The goodness of rose helps in relaxing the tired skin.', 24)
# ('Alcohol Based Hand Sanitiser With Refreshing Lemon', 'Beauty & Hygiene', 'Bath & Hand Wash', 'Bodyguard', 200.0, 250.0, 'Hand Wash & Sanitizers', 4.1, 'BodyGuard Hand Sanitizer\r\nalcohol-based\r\nrefreshing lemon\r\nKills 99.9% of germs\r\n\r\nBodyGuard is a protection and wellness range from Sirona ... (451 characters truncated) ... dyGuard Hand Sanitizer on the go. Formulated with the goodness of lemon, it kills 99.9% of germs, helping you lower the risk of contracting diseases.', 26)
# ('Vodka Glass', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Krosno - Europe', 579.0, 999.0, 'Glassware', None, 'Krosno glasses have been crafted by the finest artists and designs. These glasses combine unique design, exquisite workmanship and latest technologic ... (64 characters truncated) ... d beauty of your home and bars. All of Krosno products are recognised at home and abroad for its quality, beauty, sophistication and crystal clarity.', 26)
# ('Microwave Safe Stainless Steel Bowl Set - Red', 'Kitchen, Garden & Pets', 'Steel Utensils', 'Vinayak', 199.0, 499.0, 'Steel Storage Containers', 3.9, 'Add a dash of colour to your kitchen with these colourful and functional microwave safe stainless steel plastic coated containers with lid from Vinay ... (252 characters truncated) ... h your food is absolutely safe of any toxins. Hence it might take longer than usual to heat up in the microwave. So go ahead and buy yourself a set!!', 20)
# ('Cherry', 'Fruits & Vegetables', 'Fresh Fruits', 'Fresho', 135.0, 168.75, 'Exotic Fruits', None, 'Cherries are succulent with a sour-sweet flavor, especially red cherries. As they darken they flavor better & tasteless sour. Cherries are wealthy in ... (273 characters truncated) ... hey help improve in problems like arthritis. It is an energy-boosting fruit and still low in calories. Fresho cherries are hand-picked from the best.', 21)
# ('Face Cream - Complexion Care', 'Beauty & Hygiene', 'Makeup', 'Lakme', 203.32, 299.0, 'Face', 4.8, "This cream combines the goodness of your daily skin cream with just the right touch of make-up to give you that perfect look in just a few minutes. T ... (758 characters truncated) ...  to 5 CC Cream brings you the best of both worlds: Its skincare with a touch of makeup to give you the perfect look, for any occasion, in an instant.", 29)
# ('Ultra Nights Sanitary Pads - XXXL Wings', 'Beauty & Hygiene', 'Feminine Hygiene', 'Whisper ', 211.0, 275.0, 'Sanitary Napkins', 4.4, 'Sleep worry-free with Whisper Bindazz Nights! Whisper Bindazzz Nights pads ensure up to 0% leaks because they are 75% longer & have a wider back vs r ... (210 characters truncated) ... more absorbency\nLock core helps absorb fluid and locks it in gel form for long-lasting protection\nThe dri-weave cover provides soft, dry protection', 25)
# ('Ayurvedic Ayush Kwath', 'Beauty & Hygiene', 'Health & Medicine', 'Meghdoot', 110.0, 110.0, 'Ayurveda', None, 'Meghdoot Ayurvedic Ayush Kwath is a powerful and natural formulation to develop immunity to fight against flu and such viral infections. This formulation is suggested and recommended by ministry of Ayush- govt. Of India to stay strong immunity to stay safe during such crises.', 27)
# ('Aluminium Silver Muffin Tray & Cup cake - 6 Cavity', 'Kitchen, Garden & Pets', 'Bakeware', 'HAZEL', 219.0, 399.0, 'Bakeware Moulds, Cutters', 2.9, 'The tray has 6 Circular cupcakes (Cavity), it can let you make 6 delicious round muffins, corns, bread, puddings, jelly, muffin cakes with various tastes and so on at a time. Easy to use and clean, a good helper for baking muffins/cupcake in the kitchen.', 28)
# ('Curry Leaves', 'Fruits & Vegetables', 'Herbs & Seasonings', 'Fresho', 119.0, 148.75, 'Indian & Exotic Herbs', None, 'With dark green and glossy appearance, curry leaves have a strong flavour and release a tasty aroma when fried in hot oil.  Do not forget to check our delicious recipe - https://www.bigbasket.com/cookbook/recipes/742/curryleaves-lemonade//', 21)
# ('Slim Soft Toothbrush - Soft Bristles', 'Beauty & Hygiene', 'Oral Care', 'Colgate', 127.5, 150.0, 'Toothbrush', 4.3, 'Colgate Slim Soft Toothbrush, with 17x slimmer tip bristles vs ordinary end-rounded bristles, provides deep yet gentle mouth clean. The slimmer brist ... (229 characters truncated) ... y Colgate SlimSoft toothbrush and experience deep cleaning along the gum line and narrow gaps between teeth, so you wear a confident smile every day!', 18)
# ('Purple Body Spray', 'Beauty & Hygiene', "Men's Grooming", 'Colour Me', 641.25, 675.0, 'Body Sprays & Mists', None, "Colour Me is the of one of Milton Lloyd's wonders. Now get a long-lasting, luxury fragrance in form of different variants of Colour Me. Take advantage of the finest quality and longest lasting oils, put in the highest concentration to ensure you repeated delight.", 12)
# ('Double Walled Glass Bottle With Gray Cap - BB1243GRAY', 'Kitchen, Garden & Pets', 'Storage & Accessories', 'DP', 349.0, 679.0, 'Water & Fridge Bottles', 5.0, 'Redefine the experience of enjoying various beverages in this captivating looking bottles. The bottle is created using high-quality glass that ensure ... (73 characters truncated) ... a sleek design that can be fitted anywhere easily. It is hygienic and boasts easy to hold design. Carry anywhere and everywhere with all convenience.', 25)
# ('Charcoal Nose Strip', 'Beauty & Hygiene', 'Skin Care', 'Miss Claire', 122.5, 175.0, 'Face Care', None, 'Miss Claire Charcoal Nose Strip - This charcoal pore purifying black strips are designed to remove dirt, blackheads, excess oil & unclogs pores. This ... (149 characters truncated) ... o the dirt and oil in your pores and then they are lifted away as you remove the strip. The result is seen instantly giving you a clean & fresh look.', 21)
# ('Fresho Bread - Multigrain 400gm + Jus Amazin Almond Butter Dark Chocolate 125gm', 'Bakery, Cakes & Dairy', 'Breads & Buns', 'bb Combo', 379.0, 399.0, 'Brown, Wheat & Multigrain', None, 'Freshly Baked bread is one of lifes greatest simple pleasures and at Bigbasket we decided to give you just that. We start baking our breads once you  ... (764 characters truncated) ... eservatives and chemicals, this healthy butter has zero cholesterol and is dairy free, soy free, peanut free, gluten free and is suitable for vegans.', 14)
# ('Nacho Crisps - Sizzlin Jalapeno', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'Cornitos', 76.5, 85.0, 'Nachos & Chips', 4.2, 'Cornitos Sizzling Nacho Crisps are ready from corn and are cooked in healthier oil, which kills your appetite without making you fat. It has zero cho ... (92 characters truncated) ... he day you like. The plain heat of jalapeno peppers balanced with a fresh rounded flavor will crackle your taste buds and leave you wanting for more.', 15)
# ('Pedal Plastic Dustbin / Garbage Bin - Mini, Round, Printed, Multicolour', 'Cleaning & Household', 'Bins & Bathroom Ware', 'Princeware', 189.0, 343.0, 'Dustbins', 3.3, 'It is made of high-density polyethene. This pedal bin dustbin is foot operated and it comes with comfortable handles. They are suitable for office and personal use at home, kitchens, bathrooms or anywhere else.', 24)
# ('Green Curry Paste', 'Gourmet & World Food', 'Cooking & Baking Needs', 'Real Thai', 510.0, 510.0, 'Curry Paste, Coconut Milk', 5.0, "The traditional ingredients in Real Thai green curry paste include fresh green chillies, shallots, galangal, garlic, lemongrass, kaffir lime leaves,  ... (143 characters truncated) ... w to outstanding spiciness.\nBenefits \n1. Made of all-natural ingredients.\n2. Rich paste filled with all essential nutrients.\n3. It's easy to use.", 21)
# ('Marine After Shave Spray', 'Beauty & Hygiene', "Men's Grooming", 'Liberty', 1499.0, 1499.0, 'Shaving Care', 5.0, 'Feel the fresh sea breeze caress your skin as you surf, yacht or just lie on the beach with the Liberty Lifestyle Marine After Shave. The youthful, marine notes of this after shave bring in a feeling of bracing freshness of citrus and mint and exhilaration of violet and cedarwood.', 18)
# ('Awadhi Raita Masala', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'Keya', 70.0, 140.0, 'Blended Masalas', 3.8, 'Keya Awadhi Raita Masala is an exotic blend made from the choicest of ingredients, that are handpicked in the right proportion, gently blended and Co ... (22 characters truncated) ... taste and aroma only while cooking. Prepared by expert chefs, the magic of aroma locked Awadhi Raita Masala comes alive with great taste and flavour.', 19)
# ('Nangrow Milk Drink For Children-  Creamy Vanilla, 2 to 5 years', 'Beverages', 'Health Drink, Supplement', 'Nestle ', 550.0, 550.0, 'Children (2-5 Yrs)', 4.3, 'Children these days can be truly anything! So when it comes to their growth, we want to give them everything. Try Nangrow, a nutritious milk drink in ... (378 characters truncated) ... s Naturally Occurring Sugars **basis Rda For A 4 To A 6-year-old Child – Icmr 2010 ++1 Scoop 4.78g Approx +++1 Serve Is 33.5g Nangrow In 210 Ml Water', 16)
# ('Scrubber Pan & Grill Refill for Dish Wand', 'Cleaning & Household', 'Mops, Brushes & Scrubs', 'Dishmatic', 299.0, 299.0, 'Utensil Scrub-Pad, Glove', None, 'Dishmatic Pan & Grill Steel Scrubber Refills are designed with high-quality stainless steel to help you tackle the toughest challenges whilst protecting your hands. Suitable for use with our full range of interchangeable heads.', 18)
# ('Organic Fenugreek Seeds', 'Foodgrains, Oil & Masala', 'Organic Staples', '24 Mantra', 30.0, 30.0, 'Organic Masalas & Spices', 4.1, 'Fenugreek seeds organic or methi seeds whole are commonly known as Methi and is used regularly in Indian food preparation. The Fenugreek seeds or Met ... (141 characters truncated) ...  both for culinary and medicinal purposes. These seeds organic or methi seeds are unadulterated and has a strong spicy flavour typical for Fenugreek.', 30)
# ('Tonic - Digestive, Pancharishta', 'Beauty & Hygiene', 'Health & Medicine', 'Zandu', 132.0, 132.0, 'Ayurveda', None, 'Zandu Pancharishta is a unique Ayurvedic Digestive Tonic enriched with kindness of Ayurvedic herbs and ingredients. It acts on the whole digestive sy ... (75 characters truncated) ... estive problems like acidity, indigestion, gas, flatulence and constipation.  For Beauty tips, tricks & more visitÃƒâ€šÃ‚Â\xa0https://bigbasket.blog/', 29)
# ('Active Clean Shower Gel', 'Beauty & Hygiene', 'Bath & Hand Wash', 'Nivea Men', 191.04, 199.0, 'Bath & Shower', 3.8, 'Get the ultra clean and revitalized feeling with NIVEA Men Active Clean Shower Gel. This innovative 3-in-1 shower gel is meant for your body, face an ... (70 characters truncated) ... in while the caring formula lathers into a rich foam which keeps your skin hydrated. Get an active start to your day with this refreshing shower gel.', 11)
# ('Chia Seeds', 'Foodgrains, Oil & Masala', 'Organic Staples', 'Himalayan Natives', 360.0, 450.0, 'Cereals & Millets', 4.6, 'Himalayan Natives 100% Natural Chia Seeds are farmed and harvested with the highest quality control standards to ensure purity and consistent quality ... (11 characters truncated) ... s are high in protein. They are also loaded with antioxidants and are very high in fibre. Chia seeds are incredibly easy to incorporate in your diet.', 19)
# ('Rainbow Strands', 'Gourmet & World Food', 'Cooking & Baking Needs', 'Abbies', 299.0, 299.0, 'Baking, Cake Decorations', 4.3, 'Colourful jimmies/sprinkles make decorating your cakes, cupcakes and cookies fun and easy. Great as an ice cream topping too.', 26)
# ('Lettuce - Iceberg', 'Fruits & Vegetables', 'Fresh Vegetables', 'Fresho', 32.0, 40.0, 'Exotic Vegetables', None, 'Iceberg lettuce is a variety of lettuce with crisp leaves which grows in a spherical head resembling a cabbage. The leaves on the outside tend to be  ... (141 characters truncated) ... etest leaves in the center of the head.Do not forget to check out our delicious recipe-https://www.bigbasket.com/cookbook/recipes/2277/chicken-salad/', 19)
# ('Perfume Spray - Alter Ego', 'Beauty & Hygiene', 'Fragrances & Deos', 'Park avenue', 180.0, 240.0, "Men's Deodorants", 4.0, 'Alter EGO - Refreshing green nutmeg spicy top note with a strong ambery musky base. This perfume spray is combined with emollients, which acts as an anti-irritant and keeps you relaxed all day long.For Beauty tips, tricks & more visit https://bigbasket.blog/', 19)
# ('Perfume - Pure EDP', 'Beauty & Hygiene', 'Fragrances & Deos', 'Dkny', 5550.0, 5550.0, 'Eau De Parfum', None, 'The scent is nuanced with Transparent Jasmine, Lush Orchid and Creamy Sandalwood to play up the drop of vanilla in water. Pure DKNY is more than a fr ... (37 characters truncated) ... f being and a way to make a small difference, pure and simple. Fragarnce Type - Floral.  For Beauty tips, tricks & more visit https://bigbasket.blog/', 16)
# ('Glass Water/Juice Tumbler Set - Ceasar', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Fng', 365.0, 365.0, 'Glassware', 4.3, 'Add a touch of elegance to your home bar counter with this set. These are ideal to serve drinks to your guests in style and class! Made of a transpar ... (54 characters truncated) ... lasses. Easy to clean after use, this long-lasting glass set can be used to serve a variety of beverages to your guests. These glasses are stackable.', 30)
# ('Hibiscus Shampoo', 'Beauty & Hygiene', 'Hair Care', 'Nyassa', 750.0, 750.0, 'Shampoo & Conditioner', 3.8, 'Nyassa luxurious Hibiscus Shampoo contains Hibiscus extracts and Barely proteins that help moisturise the scalp and provide nourishment. Hibiscus ext ... (666 characters truncated) ...  medium lather. Fortified with additional proteins and a soothing floral-woodsy fragrance, this is what you need for natural and effective hair care.', 14)
# ('Apple - with No Added Sugar', 'Beverages', 'Fruit Juices & Drinks', 'Real Activ', 209.52, 270.0, 'Juices', 4.1, 'Real Activ Apple is reconstituted 100% juice', 10)
# ('Love You Like Crazy EDT For Women', 'Beauty & Hygiene', 'Fragrances & Deos', 'Dorall Collection', 419.3, 599.0, 'Eau De Toilette', 3.7, 'Check out this brilliant Love you like crazy EDP perfume for your women who is very special to you. It arrives with the enchanting aromas of Black Cu ... (318 characters truncated) ...  It is known for its feel-good factor, besides its scent adds moments and memories for you to cherish. Bathe in the aroma of its exquisite fragrance.', 27)
# ('Ultralights Highlighting Kit - Coffee Collection, Mocha Brown', 'Beauty & Hygiene', 'Hair Care', 'Streax', 160.0, 160.0, 'Hair Color', 3.3, 'Ready to give your hair gorgeous & vibrant highlights? Then order your packs of Streax Ultralights Hair Highlighting Kit right away! These easy-to-us ... (274 characters truncated) ... ves your hair improved shine & smoothness. So what are you waiting for? Give yourself a hair makeover at home with fabulous, long-lasting highlights!', 14)
# ('Hair Removal Cream For Sensitive Skin', 'Beauty & Hygiene', 'Feminine Hygiene', 'Veet', 67.5, 75.0, 'Hair Removal', 4.2, 'Get the smooth skin and the freedom to wear any look, any time with Veet. Veet Hair Removal Cream for Sensitive Skin, enriched with Aloe Vera and Vit ... (381 characters truncated) ... nd the special spatula inside the pack helps you uproot hair in one easy move. Before using this product, please read the pack precautions carefully.', 18)
# ('Fruit Juice - Delight, Mixed Fruit', 'Beverages', 'Fruit Juices & Drinks', 'Tropicana', 71.0, 110.0, 'Juices', None, 'Enjoy the refreshing and delicious taste of mixed fruits!\r\r\r\r\r\nA special 6-layer protection gives you the goodness of tasty, ready to serve fru ... (64 characters truncated) ... Did You Know?\r\r\r\r\r\nFruits are an important part of a balanced daily diet and provide the body with nutrients which are good for healthy living.', 23)
# ('Pain Relief Cream', 'Beauty & Hygiene', 'Health & Medicine', 'Moov', 152.1, 169.0, 'Everyday Medicine', 4.5, 'Moov presents their range of 100% ayurvedic pain relief creams which provide instant relief to the affected area when applied. Made with a soothing b ... (1096 characters truncated) ... ri oil, wintergreen oil and mint extract swiftly penetrate the targeted area of pain.Also available in easy-to-carry MOOV spray for easy application.', 25)
# ('Natural Ice Cream - Tender Coconut', 'Bakery, Cakes & Dairy', 'Ice Creams & Desserts', 'NIC', 350.0, 350.0, 'Ice Creams', 3.3, '100% natural ice cream made from fresh tender coconut. It contains no preservatives, no added colours or stabilisers. It is made from pure milk. It comes in hygienic and tamper-proof packaging. It comes with a perfect balance of taste and quality.', 20)
# ('Organic - Quinoa Seeds', 'Foodgrains, Oil & Masala', 'Organic Staples', 'Phalada Pure & Sure', 240.0, 240.0, 'Organic Dry Fruits', 3.0, '100% Organic Quinoa', 11)
# ('Evoke Silver Edition Him EDP Woody Perfume For Men', 'Beauty & Hygiene', 'Fragrances & Deos', 'Ajmal', 2574.0, 3300.0, 'Eau De Parfum', None, 'A flanker to the predecessor, the Silver Edition Evoke is a spicy woody fragrance that appeals to men who are urbane, tasteful and elegant. Bergamot  ... (122 characters truncated) ... m, Orange Flower, and Violet. Amber, Cedarwood, and Musk provide the fragrance with a long-lasting aroma that lingers with assured woody musky notes.', 16)
# ('Almonds - 100% Natural Premium Californian', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'Happilo', 322.0, 550.0, 'Dry Fruits & Berries', None, 'Perfect for a health snack. Time to be happy, lovely & healthy.', 29)
# ('Stevia Leaves Powder', 'Beauty & Hygiene', 'Health & Medicine', 'Bixa Botanical', 245.0, 245.0, 'Ayurveda', None, 'Stevia is a Low calorie, Natural alternative sweetener and is the best healthy sugar substitute that is extracted from the leaves of Stevia plant cal ... (1473 characters truncated) ... sted. Stevia helps to improve the function of the hormone insulin, purifies the blood and helps to reduce blood pressure when taken on regular basis.', 13)
# ('Sweet Care - Low GI Sugar', 'Foodgrains, Oil & Masala', 'Salt, Sugar & Jaggery', "Parry's", 40.0, 60.0, 'Sugar & Jaggery', 3.3, "Parry's SweetCare Low GI Sugar is clinically proven low GI sugar. Unlike regular sugar, this sugar contributes to a lower rise in blood sugar levels. ... (310 characters truncated) ...  and without any artificial taste. It is a great alternative to regular white sugar. This is healthy and helps you control the rise in blood glucose.", 29)
# ('Hand Sanitizer Gel - Orange', 'Beauty & Hygiene', 'Bath & Hand Wash', 'ZM LABS', 50.0, 50.0, 'Hand Wash & Sanitizers', 3.0, 'ZM Labs instant Hand Sanitizer gel effectively kills 99.9% bacteria, fungi and viruses and ensures your protection. It comes in a convenient bottle a ... (101 characters truncated) ... ut water. As an add on benefit, this Gel can also be used on multiple surfaces. Simply the easiest way to keep your hands and surroundings sanitized.', 13)
# ('Yellow Cloth', 'Cleaning & Household', 'Mops, Brushes & Scrubs', 'Rise N Shine', 45.0, 79.0, 'Dust Cloth & Wipes', 3.7, 'Multi-purpose Cotton Soft absorbent cloth - Useful for household cleaning, polishing, vehicle cleaning and many other purposes. Fuzz-free, very soft  ... (346 characters truncated) ... e they deserve. Package Contains 12 Piece of Cleaning Cloth.Benefits:\xa0Made of 100% cottonQuickly and easily removes dirt and grimeHighly Absorbent', 13)
# ('Nacho Chips - Cheese', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'Tasties', 125.0, 180.0, 'Nachos & Chips', None, 'Tasties brings authentic Mexicano flavors with crunchy and yummy Nachos perfect for dips and toppings or just daily snacking!', 27)
# ('Grapeseed & Sea Buckthorn Glow-Restore Face Oil Blend', 'Beauty & Hygiene', 'Skin Care', 'Plum', 658.75, 775.0, 'Face Care', 4.2, "It is 99.8% natural and 100% amazing. It is a blend of 10 oils. Meet the dry skin expert. This unique combination of 100% plant-derived oils combats  ... (1004 characters truncated) ... ed oil - contains vitamin B complex & iodine- heals. And as always, this Plum is 100% vegan, paraben-free, phthalate-free, and not tested on animals.", 25)
# ('Oats - Atta', 'Snacks & Branded Foods', 'Breakfast Cereals', 'Bagrrys', 99.0, 99.0, 'Oats & Porridge', 4.2, 'Our Oats for Atta is whole grain flour from oats, which blends easily into atta and flour based dishes. You can make your rotis, chapatis and breads healthier by simply making them wholly or partially with Bagrrys Oats for Atta.', 22)
# ('Tomato Jalapeno Sauce', 'Gourmet & World Food', 'Sauces, Spreads & Dips', 'Neo', 99.0, 110.0, 'Thai & Asian Sauces', 3.9, 'Sauces have been an integral part of the Indian consumers for decades now. To cater to the diverse Indian palate. Neo has two variants in the sauces, ... (111 characters truncated) ... sauces stay true to and close its consumers. These sauces can also be used as a marinade or a dip along with your favourite snacks for added flavour.', 23)
# ('Glass Tumbler Beone - Tall', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Fng', 365.0, 365.0, 'Glassware', None, 'Add a touch of elegance to your home bar counter with this set. These are ideal to serve drinks to your guests in style and class! Made of a transpar ... (54 characters truncated) ... lasses. Easy to clean after use, this long-lasting glass set can be used to serve a variety of beverages to your guests. These glasses are stackable.', 10)
# ('Soya Milk - Kesar Pista', 'Bakery, Cakes & Dairy', 'Dairy', 'Sofit ', 92.61, 105.0, 'Flavoured, Soya Milk', 4.2, 'Looking for a great way to kick start your day? Try the Kesar Pista flavored SOFIT! SOFIT Soya Milk is a Delicious Healthy Drink for everyone in the Family. Enriched with Soy Proteins, Omega-3, Vitamins & Calcium, it gives you Healthy Energy to do more.', 21)
# ('Quinoa Cereal - With Fruits & Nuts, Banana Flavour', 'Gourmet & World Food', 'Cereals & Breakfast', 'GoodDiet', 115.0, 210.0, 'Cereal & Granola Bars', 4.0, 'The Quinoa Cereals are enriched with the goodness of protein-rich quinoa combined with crunchy nuts and fruits with a rich banana flavour. This quinoa based cereal is a good start for your hectic day and is completely gluten-free. They do not contain any added preservatives or refined sugar.', 20)
# ('Vinegar - White', 'Gourmet & World Food', 'Oils & Vinegar', 'Neo foods ', 234.0, 260.0, 'Regular & White Vinegar', 4.5, 'Adding a splash of Neo vinegar, tends to brighten the flavors of almost any dish. But dont limit yourself to one variety, each vinegar has distinct personalities.', 29)
# ('Noodles - Chicken', 'Snacks & Branded Foods', 'Noodle, Pasta, Vermicelli', 'Top Ramen ', 15.0, 15.0, 'Instant Noodles', 4.1, 'Twist your taste with the yummy Top Ramen Chicken Super Noodles. The best noodles to accompany you in order to fulfill the tasty and healthy snack time. The delicious chicken flavoured along with the non-sticky masala flavored noodles adds oodles of taste in a meal fit for a champion.', 17)
# ('Scented Glass Cleaner - Pink', 'Cleaning & Household', 'All Purpose Cleaners', 'SOVI', 84.0, 120.0, 'Floor & Other Cleaners', 5.0, 'Sovi glass cleaner is yet another fantastic addition from the Raaso clean team. Our powerful, unique & eco-friendly formula provides you with a longe ... (1051 characters truncated) ... e but also toxin-free and are made using a potent amalgamation of science-backed with the age old secret kitchen ingredients vinegar and baking soda.', 14)
# ('Pista Biscotti', 'Bakery, Cakes & Dairy', 'Cookies, Rusk & Khari', 'Cookie Man', 265.5, 295.0, 'Bakery Biscuits, Cookies', 4.7, 'Biscotti, also known as cantucci are Italian double-baked biscuits that originated in the Tuscan city of Prato. CookieMan brings you our very own tak ... (10 characters truncated) ... ista Biscotti that perfectly compliments a hot beverage. CookieMan biscotti are carefully handcrafted and made under best in class safety standards!!', 12)
# ('Atta Bread', 'Bakery, Cakes & Dairy', 'Breads & Buns', 'Britannia', 45.0, 45.0, 'Brown, Wheat & Multigrain', None, 'Made from 51% wholewheat flour and enriched with essential B Vitamins (15% RDA from 100 gms) it is enriched with fibre with the distinct flavour of malt extract.', 11)
# ('Anti-Pigmentation Concentrate', 'Beauty & Hygiene', 'Skin Care', 'Aroma Magic ', 390.0, 520.0, 'Face Care', 3.7, 'I am 100% free of parabens, petrochemicals, sulphates, alcohol, toxic ingredients, artificial coloring and fragrance. Powered by the potent blend of essential oils of rosemary, lemon, and chamomile-infused water. I lighten blemishes, dark spots and pigmentation patches on the face and body.', 16)
# ('Cat Litter', 'Kitchen, Garden & Pets', 'Pet Food & Accessories', 'Glenand', 440.0, 440.0, 'Pet Cleaning & Grooming', 4.4, 'Made from the best quality bentonite. Its highly  absorbant  providing instant clumping. It removes odor . It safe for cats and kittens . Its non stain.', 14)
# ('Chai/Tea/Coffee Bonechina Brown & Peach Big Floral Mug', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'BP Bharat', 309.0, 436.0, 'Cups, Mugs & Tumblers', 4.0, 'Enjoy your favourite beverages in this beautiful mugs along with the various designs. Bringing to you the best and classic designs along with a varie ... (103 characters truncated) ... ou. Also, you can add some artistic style to your hot and cold beverages. The designs are new, quirky, classy, up-to-date and are a must buy for you.', 14)
# ('Daily Styling Aqua Hair Gel - Aloe Vera', 'Beauty & Hygiene', "Men's Grooming", 'Set Wet', 60.0, 75.0, 'Hair Care & Styling', 3.7, 'You’d feel a spring in your step if you could get compliments from your friends, wouldn’t you? But you often wonder how do you do that? How do you ge ... (670 characters truncated) ... rtainly gives you the look without making it look stiff. So style your hair with the New Set Wet Aqua Gel and get a soft and set hairstyle every day!', 20)
# ('Melia Face Wash', 'Beauty & Hygiene', 'Skin Care', 'Vlcc', 126.0, 140.0, 'Face Care', 3.8, 'VLCC Melia Face Wash is formulated with melia extract that helps in deep cleansing without leaving the skin dry. It manages the extra oil thus protec ... (20 characters truncated) ... pimples. It protects the skin against blackheads, dryness, pigmentation, dullness, wrinkles and cures the sun damage with its rich Vitamin C content.', 25)
# ('Thandai Kesar Badam', 'Beverages', 'Fruit Juices & Drinks', 'Delight Foods', 360.0, 360.0, 'Syrups & Concentrates', 4.7, 'Invented by a famous Hakim back in 1890, our Thandai has 40% more Thandai Mixture (Badam, Elaichi, Saunf, Khus Khus, Tarbooz Ki Giri, Safed Mirch) ma ... (1543 characters truncated) ... idation Vegetarian.Best Before 6 Months from date of packing if sealed. 3 months from date of packing after opening. Keep refrigerated after opening.', 16)
# ('Stainless Steel Colander/Basket/Strainer - 20 cm', 'Kitchen, Garden & Pets', 'Kitchen Accessories', 'Elephant ', 386.1, 429.0, 'Strainer, Ladle, Spatula', 3.9, 'Straining is an everyday task in most kitchens, for which a tough, durable, easy-to-clean and maintain strainer is a necessity. Crafted from high gra ... (220 characters truncated) ... pouring and filtering. The strainer is a heavy duty which is suitable for both home and commercial use. They are resistant to rust and easy to store.', 10)
# ('Baked Coconut Chips - Coffee & Cinnamon', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'By Nature', 55.0, 55.0, 'Healthy, Baked Snacks', None, 'By Nature Baked Coconut Chips is an irresistibly delicious snack that is perfect to be had any time of the day. Mildly sweet & delicately seasoned, t ... (202 characters truncated) ... n the fingers of your one hand. Simple ingredients & extraordinary taste combine to form a snack so good you will find it hard to stop after one bag.', 23)
# ('Herbal Aloe Vera Moisturiser', 'Beauty & Hygiene', 'Skin Care', 'Khadi Natural', 165.0, 165.0, 'Face Care', 4.5, 'Khadi Natural Aloe-vera Moisturizer possesses great moisturising properties. It is really beneficial for dry skin. This natural moisturiser keeps the skin hydrated and enhances its resilience. It also supplies oxygen to the skin, which strengthens the skin tissues and maintains the skin healthy.', 17)
# ('Cheese Spread - Garlic', 'Bakery, Cakes & Dairy', 'Dairy', 'Milky Mist', 95.0, 95.0, 'Cheese', 4.1, 'Milky Mist Premium Cheese Spread is a good supply of calcium and milk proteins. Cheese tastes excellent between toasted wheat breads along with cucumber and tomato slices. It is best for adding mouth-watering flavor to parathas, rotis, dosas.', 21)
# ('100% Melamine Quarter/Half Plate - Black', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Iveo ', 259.0, 296.0, 'Plates & Bowls', 3.9, 'This plate is used as a side plate. It is used to serve the side dishes, mainly an appetizer. A plate can also be used for ceremonial or decorative p ... (57 characters truncated) ... ape or made of any water-resistant material. Generally, plates are raised around the edges, either by a curving up, or a wider lip or raised portion.', 23)
# ('Juice - Lauki & Amla', 'Beverages', 'Fruit Juices & Drinks', 'Patanjali', 200.0, 200.0, 'Juices', None, 'Patanjali Lauki-Amla Juice has all the smart qualities of vegetables like Lauki and Amla. It is usually respected for ensuring good health with its h ... (7 characters truncated) ... tary content. It is established to have healing value that can cure many ailments such as urinary disorders, diabetes, aid weight loss and digestion.', 28)
# ('Rush Deodorant Spray - Men', 'Beauty & Hygiene', 'Health & Medicine', 'Kamasutra', 290.0, 290.0, 'Sexual Wellness', 3.5, 'Discreet love-notes! Raised eyebrows. Heads turn! Admiring gazes! And a man who triggers a rush of longing in every woman he meets! Fan the flames of desire with the woody and masculine fragrance of Rush!', 11)
# ('Safety Pin', 'Cleaning & Household', 'Stationery', 'B Vishal', 80.84, 90.0, 'Scissor, Glue & Tape', 4.2, 'Perfect Safety pins commonly used to fasten pieces of fabric or clothing together. Ideal for holding clothes together. Frequently used by women for tying up sarees. It can be used by anyone for any purpose.', 23)
# ('Raw Coffret For Men', 'Beauty & Hygiene', 'Fragrances & Deos', 'Skinn by Titan', 1515.25, 1595.0, 'Perfume', 1.0, 'The first shower of rain on a hot summer day is synonymous with freshness, bringing about a sense of rejuvenation. Raw draws its inspiration from thi ... (490 characters truncated) ... lend of beautiful woods. A precious combination of Patchouli from Indonesia, and Gaiac wood. It is skin-friendly since it is dermatologically tested.', 25)
# ('Lunch Box - Mark 3 Deluxe, Brown', 'Kitchen, Garden & Pets', 'Storage & Accessories', 'Cello', 519.0, 687.0, 'Lunch Boxes', 3.6, 'Cello has made sure that when we leave the house, we do not have to leave the comforts of home behind. This trend setter series will match up your el ... (183 characters truncated) ... bility. You can carry different kinds of food without the fear of leakage. This lunch set is perfect for carrying lunch to office, school or college.', 30)
# ('Pink Salt/Uppu Powder', 'Foodgrains, Oil & Masala', 'Salt, Sugar & Jaggery', 'Himalayan Natives', 149.25, 199.0, 'Salts', 4.1, 'Himalayan Natives 100% Natural Himalayan Pink Salt is a naturally harvested unrefined salt with high nutritive value. It consists of trace nutrients  ... (6 characters truncated) ... s potassium, magnesium, calcium, and iron that are great for overall health and are also responsible for its characteristic natural light pink tinge.', 15)
# ('Moong Dal 1 kg + Channa Dal 1 kg + Urad Dal - Split 500 gm', 'Foodgrains, Oil & Masala', 'Dals & Pulses', 'bb Royal', 300.0, 465.0, 'Toor, Channa & Moong Dal', None, 'Moong dal is one of the most popular lentils eaten across India. Packed with protein, BB Royal moong dal packs deliver the finest selection of lentil ... (1011 characters truncated) ... omplex vitamins, potassium and calcium.  Click here for unique and delicious recipes - https://www.bigbasket.com/flavors/collections/230/dals-pulses/', 12)
# ('USB String Fairy Lights 3M 30 LED Heart Bead Gold Chain For Decoration', 'Kitchen, Garden & Pets', 'Appliances & Electricals', 'Mansaa', 119.0, 399.0, 'CFL & Led Bulbs', 3.9, "Warm White Heart Bead String Lights: 30 beautiful warm white LEDs entailed with gold colour premium quality heard beads will create excellent illumin ... (1620 characters truncated) ... gns, furniture and something else; the copper wire lights have been wound around a wire coil so that it is easy to untangle and storage for next use.", 26)
# ('Raw Manuka Honey K Factor - 12+', 'Gourmet & World Food', 'Sauces, Spreads & Dips', 'Wedderspoon', 3500.0, 3500.0, 'Honey & Maple Syrup', None, 'Manuka Honey is raw, never pasteurized, non-GMO Project verified Manuka Honey, traceable from hive to home. Enjoy this easy-to-use, no drip squeeze b ... (469 characters truncated) ... notes and caramelized sugars with hints of pepper and ginger. No need to refrigerate once opened.\xa0Raw Honey - 100% Raw, Unpasteurised Manuka Honey', 22)
# ('Emasol Disinfectant Toilet Cleaner', 'Cleaning & Household', 'All Purpose Cleaners', 'Emami', 60.9, 70.0, 'Floor & Other Cleaners', 3.7, 'Emasol Disinfectant Toilet Cleaner has BGV24™, an advanced formulation which contains a powerful combination of Antimicrobials that kills bacteria &  ... (137 characters truncated) ... is the first product in India that delivers up to 24 HOURS PROTECTION by killing 99.99% bacteria & GERMS in 5 minutes and has a refreshing fragrance.', 30)
# ('Organic Cumin Seeds/Jeera/Jeerige', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'Earthon', 169.0, 169.0, 'Powdered Spices', None, "Earthon's Cumin Seeds (Jeera)) is the best quality, organically grown, no preservative, no artificial colour and free from harmful chemicals or pesticides. It is high grade. 100% pure and natural. Cumin seed have an aromatic odour and bitter taste.", 13)
# ('Chai/Stainless Steel Coffee Mug - Good Ideas, Double Walled', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Hot Muggs', 415.0, 415.0, 'Cups, Mugs & Tumblers', None, 'A perfect mug for coffee lovers. It is a stainless steel double-walled mug which can retain hot inside and keep outside at normal temperature. It has ... (308 characters truncated) ...  of a coaster. The handle is attached to the body of the mug by brazing to avoid any gaps and make it cleaner and less susceptible to bacteria/germs.', 30)
# ('SuperLite Advanced - Sunflower Oil', 'Foodgrains, Oil & Masala', 'Edible Oils & Ghee', 'Sundrop', 1340.0, 1340.0, 'Sunflower, Rice Bran Oil', 4.3, 'Sundrop Super Lite Advanced with added DMPS (Dimethyl Polysiloxane) ensures that the absorption of oil is less while cooking, as compared to any ordi ... (245 characters truncated) ... n essential fatty acid vital for the proper functioning of the body.Its ideally for Cooking.\nStore in cool and dry place, away from direct sunlight.', 14)
# ('Smart Edible Oil - Enriched With Vitamin A, D , E & K', 'Foodgrains, Oil & Masala', 'Edible Oils & Ghee', 'Oleev', 179.01, 185.0, 'Blended Cooking Oils', 4.2, 'Oleev Smart is a multi-source healthy oil with a special Vitafit formula, comprising of Vitamins A, D, E & K along with Oryzanol & Omega Fatty Acids. ... (701 characters truncated) ... bsorption Technology. Oil-O-Meter in Oleev Smart, helps you track usage of oil in your food; hence you need not worry how much oil you are consuming.', 10)
# ('Rose Hexagon Bath Gift Set - 100% Natural & Organic', 'Beauty & Hygiene', 'Bath & Hand Wash', 'Soulflower', 1050.0, 1500.0, 'Bathing Bars & Soaps', None, 'An appealing, reusable and handmade box which comprises of different spa products that will give you the ultimate bath experience along with spreading a soothing and exotic aroma. This floral aroma gift set distinctly depicts romance and love and is a perfect gift for your loved one.', 14)
# ('Fairness Naturals Diamond Bleach', 'Beauty & Hygiene', 'Skin Care', 'Fem', 62.4, 78.0, 'Face Care', 4.3, 'The bleach brings out a long-lasting radiance with a touch of the diamond. Experience the most convenient way to get sparkling skin. With real diamon ... (19 characters truncated) ... ient, FEM Diamond Creme Bleach ensures that your skin rejuvenates to the core. Its health restored, skin continues glowing even long after bleaching.', 22)
# ('Ananas Flower/Ananas Huvu', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'bb Royal', 30.0, 30.0, 'Whole Spices', 4.1, 'Star anise is the dried, star-shaped fruit of Illicium verum. It is dark brown in colour with eight segments. It has a sweetish liquorice taste. It is a major component of garam masala, in Indian cuisine. It has a sweet but pungent, fennel-like aroma with a spicy warmth.', 21)
# ('Hot Chocolate Drink Powder Mix', 'Beverages', 'Health Drink, Supplement', 'Cadbury', 311.5, 350.0, 'Men & Women', 4.3, 'Cadburys Drinking Chocolate is the perfect way to make milk enjoyable for your children. It has an authentic chocolate taste that is a joy to every tongue, old and young. \r\r\nA treat for all hot chocolate drink lovers, to be enjoyed with friends and family!', 27)
# ('Toffees - Butter', 'Gourmet & World Food', 'Chocolates & Biscuits', 'Sapphire', 150.0, 150.0, 'International Chocolates', 3.1, 'Milk delicious', 17)
# ('Baby Massage Oil', 'Baby Care', 'Baby Bath & Hygiene', 'Himalaya Baby', 400.0, 400.0, 'Baby Oil & Shampoo', 4.3, 'A daily massage with Himalayas Baby Massage Oil helps in improving babys growth and development. Infused with Olive Oil and Winter Cherry, Baby Massa ... (39 characters truncated) ... enough to use on babies. It is a light and non-staining oil which can be used before bathing as a massage oil as also for moisturizing after bathing.', 16)
# ('Solitaire Multipurpose Plastic Basket 224 Without Lid - Assorted Colour', 'Cleaning & Household', 'Bins & Bathroom Ware', 'Aristo', 149.0, 189.0, 'Laundry, Storage Baskets', 3.5, 'Premium Quality BPA Free basket having a smooth finish, highest quality, lightweight and appealing design.\xa0Multi-Utility Baskets: - Store anything and everything, from fruits, vegetables, pantry items, toiletries, beauty products, school supplies, mail, magazines and more.', 24)
# ('Shatavari Capsules', 'Beauty & Hygiene', 'Health & Medicine', 'ORGANIC INDIA', 205.0, 205.0, 'Supplements & Proteins', 4.3, 'These Shatavri (means one who possess a hundred husbands) capsule are a versatile traditional plant used in a variety of serious diseases. It is considered both a general tonic and a female reproductive tonic.', 26)
# ('Masala - Kulambu Chilly', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'Aachi', 53.1, 59.0, 'Blended Masalas', 4.2, 'Aachi Kulambu Chilly Masala is made from fresh and natural ingredients in accurate compositions. This masala is acclaimed for its high aroma, brillia ... (27 characters truncated) ...  add an extra flavour to your food which is recognized for its mouthwatering taste process to make sure for accurate quality, composition and purity.', 25)
# ('Absolute Repair Concentrate', 'Beauty & Hygiene', 'Skin Care', 'Kaya Clinic', 2040.0, 2400.0, 'Face Care', None, 'Delay the signs of ageing with kaya absolute repair concentrate. Containing glycosaminoglycans (gag) complex, this non-oily formulation penetrates de ... (64 characters truncated) ... , protects and stimulates cell renewal & turnover, reduces fine lines and results in firmer skin. Formula researched and developed by dermatologists.', 27)
# ('Pedal Plastic Dustbin / Garbage Bin - Blue', 'Cleaning & Household', 'Bins & Bathroom Ware', 'Laplast', 209.0, 249.0, 'Dustbins', 3.0, 'Our 8 L pedal bins are ideal for keeping garbage covered and mosquito-free. It is available in different vibrant colours to help in garbage segregation.', 21)
# ('Stainless Steel Lunch Box With Insulated Bag - HL-1331', 'Kitchen, Garden & Pets', 'Steel Utensils', 'Steel Lock', 639.0, 849.0, 'Steel Lunch Boxes', 3.8, 'This Stainless Steel With plastic Lid and Silicone Seal has the unique Silicon which keeps food items fresh longer and it prevents spills. The insula ... (168 characters truncated) ... ood container with sturdiness for complete meal car. It is ideal to carry meals/fruits or any food items to work, travel, school, college outing etc.', 12)
# ('Cookies & Cream', 'Gourmet & World Food', 'Chocolates & Biscuits', 'Rage', 340.0, 340.0, 'Luxury Chocolates, Gifts', None, 'Cookies and cream is a unique twist on the classic flavour combination..if you are a chocolate lover then you will relish the delicious combination o ... (77 characters truncated) ... u will experience the classic flavour packed especially for you by rage chocolatier. This chocolate promises to deliver a delicious taste experience.', 26)
# ('Chicken Biryani Masala', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'Mdh', 55.0, 55.0, 'Blended Masalas', 3.9, 'This is a mixed blend of various spices and ingredients used to give your Chicken Biryani Masala amazing spicy taste. Cook now delicious biriyani at home for your loved ones with this amazing spice mixtures.', 14)
# ('Cucumber Cell Rejuvenating Moisturising Gel', 'Beauty & Hygiene', 'Skin Care', 'Biocare ', 299.0, 299.0, 'Body Care', 3.4, 'Give a nourishing treat to your skin with BioCare Cucumber Cell Rejuvenating Moisturizing Gel. It is enriched with the rejuvenating Cucumber extracts ... (201 characters truncated) ...  you replenished and rejuvenated skin. Adds moisture and gives healthy-looking, soft and supple skin. It is enriched with soothing cucumber extracts.', 10)
# ('Organic Sprouts Mixed Gram', 'Fruits & Vegetables', 'Cuts & Sprouts', 'Fresho', 22.0, 27.5, 'Fresh Salads & Sprouts', None, 'Sprouts Mixed gram are best for health which contains greater concentration of nutrients like Vitamin E, A, C & K, iron, potassium, phyto chemicals,  ... (455 characters truncated) ... of hair follicles.\r\n Product image shown is for representation purpose only, the actually product may vary based on season, produce & availability.', 11)
# ('Garnet LED Bulb -12 Watt, White, Cool Day, B22', 'Kitchen, Garden & Pets', 'Appliances & Electricals', 'Wipro', 179.0, 295.0, 'CFL & Led Bulbs', 3.9, 'The high brightness LED comes with an efficacy up to 100lm/W. It has wide coverage with a 240-degree beam angle. It comes with an aluminium heat sink ... (145 characters truncated) ... on up to 2.5KV. It is suitable for commercial and industrial appliances. It comes with diffuser optics for a glare-free light which is safe for eyes.', 27)
# ('Chewing Gum - Peppermint', 'Snacks & Branded Foods', 'Chocolates & Candies', 'Doublemint', 5.0, 5.0, 'Mints & Chewing Gum', 4.2, 'Opportunities to connect with someone new happen often, but it can feel nerve-wracking and never lasts for long. Doublemint’s voice uses humour to re ... (641 characters truncated) ... ying, working out or even virtually meeting new people. Now with Wrigley’s Doublemint, you will never miss out on that ultimate moment of connection!', 17)
# ('Siah Jeera', 'Gourmet & World Food', 'Cooking & Baking Needs', 'REGENCY', 99.0, 109.0, 'Herbs, Seasonings & Rubs', 4.4, 'Prepare delicious curries, biryani and rice dishes. North Indian and Moghul cuisine, and raita using Regency siah jeera. The imperial taste of Regenc ... (258 characters truncated) ... d by the company. Regency group has a global network spread over 30 countries and gives priority to the outstanding quality of dry fruits and spices.', 16)
# ('Deospray For Men - Intense, No Alcohol', 'Beauty & Hygiene', "Men's Grooming", 'Cinthol', 185.25, 195.0, "Men's Deodorants", 3.5, 'Cinthol Deo spray Intense with a masculine fragrance keeps you active all day. Cinthol skin-safe deos have no alcohol. Keep your skin safe from damage and irritation. Shake well before use. Hold can upright and spray from 15cms away on underarms and body for best effect.', 10)
# ('Darjeeling Green Tea - Ahina Long Leaf', 'Beverages', 'Tea', 'Teamonk', 385.0, 550.0, 'Exotic & Flavoured Tea', 1.0, 'The state of being perfectly well in body, soul (mind, will and emotions) and spirit, is nothing but the feeling of being Whole; just like our Ahina  ... (286 characters truncated) ... e resultant brew that flows into your cup is a smooth, gleaming tea that reflects the keen spirit of this special tea with a fresh, aromatic flavour.', 16)
# ('Cooking Butter - Unsalted', 'Bakery, Cakes & Dairy', 'Dairy', 'Nandini', 374.0, 440.0, 'Butter & Margarine', 4.1, 'You will be simply amazed at the soft smooth texture of Nandini unsalted butter which comes from pasteurized cream. This tasty delight is absolutely  ... (48 characters truncated) ...  Nandini is a household name and a trusted brand from Karnataka which has been producing some of the finest milk and milk products since a long time.', 17)
# ('Purifying Cleanser 100 ml + Purifying Toner 100 ml', 'Beauty & Hygiene', 'Skin Care', 'Kaya Clinic', 502.0, 700.0, 'Face Care', None, "Purifying Cleanser: Cleanse your pores from deep with kaya purifying cleanser. It removes excess oil, dirt and impurities. containing salicylic acid  ... (569 characters truncated) ... ng your skin comfortable and refreshed. The toner further prepares you for the treatment of acne. Formula researched and developed by dermatologists.", 13)
# ('Baby Skin Care Wipes - Cherry Blossom', 'Baby Care', 'Diapers & Wipes', 'bigbasket', 99.0, 169.0, 'Baby Wipes', 4.3, 'bigbasket Wet Wipes are made from finest quality material which gives it a distinct honey comb look. Ingredients used in these wipes are absolutely s ... (229 characters truncated) ... by hygiene, make-up remover, sanitizing your face and hand after a long drive, sports or any other situation where you need a quick hygiene solution.', 14)
# ('Penne Rigate - Whole Wheat', 'Gourmet & World Food', 'Pasta, Soup & Noodles', 'Colavita', 340.0, 340.0, 'Pastas & Spaghetti', 5.0, 'Colavita Penne Rigate is diagonally cut tubular shapes with ridged shells. It is flexible in size and figure. This imported Italian pasta is complete ... (490 characters truncated) ... r homeland to produce superb pasta using only 100% durum wheat semolina and fresh mountain spring water with no salts or artificial ingredients added', 17)
# ('Kali Mirchi Drop', 'Foodgrains, Oil & Masala', 'Masalas & Spices', 'Spice Liquid', 145.0, 145.0, 'Whole Spices', None, 'Spice Liquid Turmeric Black Pepper Drop is an all-natural blend that has major benefits for your body and brain. It is also a herbal antioxidant, low ... (380 characters truncated) ... ing or even at your table. Consistent personalized taste, packed in easy to use glass bottles, make Spice Drop a handy companion even when traveling.', 20)
# ('Office Mousepad - Regular', 'Cleaning & Household', 'Stationery', 'KCL', 208.0, 297.0, 'Electronic Accessories', None, 'KCL Office and Home Mousepad come in assorted colours with radiation protection. Made from Natural rubber and fabric, it can be used by all age groups.', 21)
# ('Absolut Repair Lipidium Instant Reconstructing Masque', 'Beauty & Hygiene', 'Hair Care', 'LOreal Professionnel', 820.0, 820.0, 'Hair & Scalp Treatment', 3.8, "Suffering from very damaged hair? Looking for a masque that will restore hair's health? Look no further. Loreal Professionnel Absolut Repair Lipidium ... (710 characters truncated) ... st reconstructing ingredients to replenish all hair zones and create an insulating barrier to lock in essential nutrients to restore healthy tresses.", 12)
# ...
# ('Red Non Alchoholic Fruit Wine', 'Gourmet & World Food', 'Drinks & Beverages', 'Baron De Bercy', 400.0, 400.0, 'Non-Alcoholic Beer, Wine', 3.8, 'A Nonalchoholic Beverage Having Polyphenols To Improve Haemoglobin Reducing Cholestrol Level', 10)
# ('Spacio Polka Dot Printed Plastic Container Set - Assorted Colour', 'Kitchen, Garden & Pets', 'Storage & Accessories', 'JOYO', 149.0, 222.0, 'Containers Sets', 4.0, 'Organize your kitchen with the right kind of storage containers from the house of joyous world. These are made from fine quality materials. These containers will keep the food fresh and safe for long hours. Furthermore, these containers are easy to wash and are a great addition to your kitchen.', 20)
# ('Furglow - Coat Conditioner', 'Kitchen, Garden & Pets', 'Pet Food & Accessories', 'Himalaya Pet Care', 310.0, 310.0, 'Pet Collars & Leashes', 3.8, 'Pets coat and skin condition is a direct reflection of its health status. Balanced Omega 6 and Omega 3 (Essential Fatty Acids) fatty acids are essential for skin health, promotes cell membrane and nerve cell formation. Zinc plays a vital role in preventing scaly dermatitis and hair loss.', 11)
# ('Criss Cross Toothbrush With Neem Extract - Medium', 'Beauty & Hygiene', 'Oral Care', 'Oral-B', 150.0, 150.0, 'Toothbrush', 4.1, "Oral-B is the world's No. 1 toothbrush brand used and recommended by dentists worldwide, which brings to you and your family revolutionary brushing s ... (254 characters truncated) ...  bristles hit areas where plaque builds up, and CrissCross bristles flex and straighten to get in-between teeth while still being gentle on your gums", 15)
# ('Geometry Box - Asteroid', 'Cleaning & Household', 'Stationery', 'Classmate', 238.0, 250.0, 'Pen, Pencils', 4.3, 'Classmates Asteroid Geometry Box is a set of essential geometrical instruments used by school children, mathematicians and scientists alike. It comes ... (201 characters truncated) ... ical instrument box is the answer to your question for drawing complex diagrams and calculating those complicated geometrical measurements with ease.', 27)
# ('100% Melamine Popcorn Bowl - Blue', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Iveo ', 129.0, 200.0, 'Plates & Bowls', 4.3, 'Iveo Melamine products are made from 100% pure melamine which is 100% food-grade in nature. These are heat resistant, break-resistant, freezer safe,  ... (94 characters truncated) ... e oven for the re-heating purpose only. These are stain-resistant products so there will be no food stain mark on it. These are also dishwasher safe.', 17)
# ('FunFoods Veg Mayonnaise Original', 'Snacks & Branded Foods', 'Spreads, Sauces, Ketchup', 'Dr. Oetker', 39.0, 39.0, 'Mayonnaise', 4.2, "Veg Mayonnaise is a FunFoods innovation that was done keeping in view that many Indians are vegetarian. It is rich, smooth and creamy. Its neutral an ... (241 characters truncated) ... ayonnaise. Make your sandwiches, wraps, macaroni and other exciting recipes, saucier, creamier, juicer. Comes in a smaller pack for easy application.", 28)
# ('Protect & Care Deodorant Roll On - No Skin Irritation & 48h Freshness', 'Beauty & Hygiene', 'Fragrances & Deos', 'Nivea Men', 195.02, 199.0, "Men's Deodorants", 4.5, 'Get the perfect combination of odour protection and skincare with the NIVEA MEN Protect & Care Roll-On. It keeps body odour in check, leaving you free to carry on with the day with confidence. The 0% Alcohol formula keeps you fresh without hurting your underarm skin.', 21)
# ('MaxFresh Toothpaste Gel - Anticavity, Spicy Fresh, Saver Pack', 'Beauty & Hygiene', 'Oral Care', 'Colgate', 115.0, 170.0, 'Toothpaste', 4.3, 'Colgate MaxFresh Spicy Fresh Gel Toothpaste comes with cooling crystals which help in keeping you refreshed for a long time. Experience intense cooli ... (311 characters truncated) ... ia‚¬„¢s No. 1 brand recommended by dentists and offers unique oral hygiene solutions to ensure complete protection against germs and plague build-up.', 13)
# ('Nacho Crisps - Peri Peri', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'Cornitos', 76.5, 85.0, 'Nachos & Chips', 4.2, 'Experience the heat of Peri Peri chilli with tangy lemon flavour and then feel the warm African glow. Crispy tortilla chips made from stone ground no ... (214 characters truncated) ... ked in corn oil which makes it a healthy snack option as it has zero cholestrol and transfat. The perfect snack for a movie date or a picnic outside!', 11)
# ('Instant Noodles - Spicy Shrimp Flavour', 'Gourmet & World Food', 'Pasta, Soup & Noodles', 'Koka', 94.5, 105.0, 'Imported Noodles', 4.0, 'No Preservatives, No Artificial Colouring, No Trans Fat', 13)
# ("Tick'et to Fleadom Dry Shampoo For Dogs", 'Kitchen, Garden & Pets', 'Pet Food & Accessories', 'Captain Zack', 99.0, 99.0, 'Pet Cleaning & Grooming', None, '1) No Rinse Defence Against Ticks and Fleas: Captain Zack Tick’et To Fleadom keeps your dog clean, repels ticks and maintains healthy skin, in betwee ... (1418 characters truncated) ... y your dog flea shampoo, it is very effective in keeping your dog’s coat healthy and hydrated.\n11) No Harmful Chemicals and No Artificial Fragrances', 10)
# ('Vanilla Ice Cream', 'Gourmet & World Food', 'Dairy & Cheese', 'Haagen-Dazs', 225.0, 225.0, 'Gourmet Ice Cream', None, "Some things are so good in their simplest forms that there's no need to insert to them. The Haagen-Dazs vanilla flavor is one of them. It is scrumpti ... (148 characters truncated) ...  of pure, sweet cream and exclusively imported vanilla creates a sugary scent of exotic spice and a characteristic taste that lingers on your tongue.", 25)
# ('Kitchen Cleaner, Disinfectant & Insect Repellent', 'Cleaning & Household', 'All Purpose Cleaners', 'Herbal Strategi', 115.0, 130.0, 'Kitchen, Glass & Drain', 4.3, 'Remove stains too, for a germ/insect free, non-toxic, safe no side effect, effective on different types of surfaces, a unique blend of plant extracts and aromatic oils.', 24)
# ('Herbal Lemon Facial Massage Cream', 'Beauty & Hygiene', 'Skin Care', 'Olivia', 191.25, 225.0, 'Body Care', 3.2, 'Get a toned complexion that’s free from dirt and grime. The Olivia Lemon Facial Massage Cream helps replenish the skin leaving you with a soothing glow.', 24)
# ('Chia Quinoa Cookies', 'Gourmet & World Food', 'Sauces, Spreads & Dips', 'Prasukh', 76.5, 85.0, 'Jams, Marmalade, Spreads', 3.3, 'The Energy Cookies get its name because they\'re packed with "good-for-you" ingredients that ramp your body up with energy, nutrients and even Omega- ... (142 characters truncated) ... cookie enriched with chia that crackles in your mouth in every bite. A healthy anytime snack u cannot resist. . No Preservatives added, 100% Natural.', 20)
# ('Cookies - Butter Vanilla', 'Bakery, Cakes & Dairy', 'Cookies, Rusk & Khari', 'Momkhatai', 120.0, 120.0, 'Bakery Biscuits, Cookies', 3.3, 'Momkhatai Butter Vanilla are classic nankhatai cookies with the goodness of butter and vanilla. They are a delicious snacking option and are made using quality ingredients that can be relished anytime. They are also ideal to carry on-the-go, or can be paired with tea, coffee or milk.', 11)
# ('Notebook - King Size, Four Line, Ruled', 'Cleaning & Household', 'Stationery', 'Classmate', 47.0, 48.0, 'Notebooks, Files, Folders', 4.2, 'Classmate Notebooks are made to the highest quality standards. Made from superior quality paper and pulp, the pages are whiter, brighter and smoother ... (178 characters truncated) ... rable as ever. These notebooks come with a wide variety of covers with activities and trivias to make every classmate notebook unique in its own way.', 14)
# ('Organic - Sunflower Oil', 'Foodgrains, Oil & Masala', 'Organic Staples', 'Phalada Pure & Sure', 335.0, 335.0, 'Organic Edible Oil, Ghee', 4.3, 'Pure & Sure is a range of Certified Organic Foods Products from Phalada Agro, It is a natural step to extend our know-how and expertise of Organic fo ... (943 characters truncated) ... d Processing Facility with more than 10 years of experience in Organic Agriculture, Phalada works with more than 1000 certified farmers across India.', 13)
# ('Quista Pro Advanced Whey Protein Formula fortified with Power Herbs - Chocolate', 'Beauty & Hygiene', 'Health & Medicine', 'Himalaya', 4500.0, 4500.0, 'Supplements & Proteins', 4.0, 'Quista Pro is a whey protein blend that helps gain muscle mass. It is among the first protein blend that contains all 3 forms of whey (WPC, WPI, WPH) ... (299 characters truncated) ... urine, calcium that can be suitably consumed with water or milk. Quista Pro comes in the most globally loved flavour, which is the chocolate flavour.', 13)
# ('Steel Spoon Set - Desert, Monde Small', 'Kitchen, Garden & Pets', 'Crockery & Cutlery', 'Anjali', 169.0, 225.0, 'Cutlery, Spoon & Fork', 3.8, 'Anjali spoons simple yet elegant design adds class to the dining area and are a must for every home. They are made using stainless steel that enhance the durability of the utensils, and helps them retain their shine even after multiple wash cycles.', 29)
# ('Acidshoonya Tablet', 'Beauty & Hygiene', 'Health & Medicine', 'Meghdoot', 165.0, 165.0, 'Ayurveda', 3.9, "The Meghdoot's Acidshoonya Tablet\xa0helps treat Dyspepsia, digestive disorders, duodenal ulcers, as well as enlargement of the liver and spleen. This may help in treating indigestion, constipation and urinary disorders. It is made using ayurvedic formulation that it is safe to use.", 15)
# ('Herbal Rose & Apricot Walnut Facial Scrub', 'Beauty & Hygiene', 'Skin Care', 'Khadi Natural', 250.0, 250.0, 'Face Care', 4.4, 'Rose and apricot walnut face scrub helps in reducing skin darkening and protects the skin from sunburn and sun damage.It also helps to retain skin mo ... (16 characters truncated) ... ch in vitamins which softens skin, heals damaged skin, reduces wrinkles, removes blackheads and maintains skin elasticity with excellent exfoliation.', 24)
# ('Embellish Skin Lightening Serum', 'Beauty & Hygiene', 'Skin Care', 'Organic Harvest', 1525.75, 1795.0, 'Face Care', 4.2, 'Achieve an everlasting illuminated skin by incorporating this wonder product into your daily regime! The gentle lightening serum, with the superb pro ... (43 characters truncated) ... ly penetrates into the skin and reduces melanin formation and tackles excessive skin pigmentation and sun spots brighten and lightens the complexion.', 10)
# ('Popcorn - French Butter & Pink Salt', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', '4700BC', 31.5, 35.0, 'Gourmet Popcorn', 4.1, 'High-quality mushroom corn popped in olive oil, French butter and sprinkled with Pink Salt. 4700BC gourmet popcorn is prepared fresh in a state of th ... (118 characters truncated) ... e interesting popcorn before an occasion is considered auspicious, gifting someone 4700 BC’s gourmet popcorn would only make you a paragon of virtue.', 11)
# ('Brass Dhoop Aarti With Wooden Handle,No.3', 'Cleaning & Household', 'Pooja Needs', 'Trm', 239.0, 495.0, 'Other Pooja Needs', 4.0, 'Dhoobakal is a vessel used for burning the Dhoop Sambrani to purify the air. It is made of Brass with a wooden handle for a firm grip. It also avoids ... (222 characters truncated) ...  soothing, spiritual and calm effect for the body and thus relieves the tension. It can be removed into parts easily for washing and is long-lasting.', 28)
# ('Toilet Cleaning Brush - Round With Holder (Big)', 'Cleaning & Household', 'Mops, Brushes & Scrubs', 'Liao', 189.0, 349.0, 'Toilet & Other Brushes', 3.8, 'This round toilet brush is made up of virgin quality plastic handle and acid-proof polypropylene bristles. It is easy to grip, can be washed repeatedly, and it cleanses the toilet efficiently and completely.  Product can be only returned if it is not used and is in packed condition.', 23)
# ('Organic Powder - Garam Masala', 'Foodgrains, Oil & Masala', 'Organic Staples', 'Organic Tattva', 152.0, 160.0, 'Organic Masalas & Spices', 4.2, 'Organic Tattva Garam masala is a famous spice blend used all over India and neighboring countries too. It is prepared of more than 10 types of spices ... (90 characters truncated) ...  tempering. It can be used only or along with other seasonings and spice powders. It has a spicy flavor but is not fiery hot similar to chili powder.', 22)
# ('Powder - Baking', 'Snacks & Branded Foods', 'Ready To Cook & Eat', 'Kwality', 38.0, 38.0, 'Home Baking', 3.7, 'Kwality Baking Powder Directions for use: Use 10g of Kwality baking powder for baking 450g of flour mix. Mix throughly with the flour in dry state by ... (42 characters truncated) ... o or three times essentially. In order to have the best velvety texture, volume and lightness, the ready dough should immediately be put in the oven.', 12)
# ('Apple Cider Vinegar Shampoo', 'Beauty & Hygiene', 'Hair Care', 'Morpheme Remedies', 499.0, 499.0, 'Shampoo & Conditioner', 5.0, 'Say no to dull, lifeless, dry and damaged hair with Morpheme Remedies Apple Cider Vinegar Shampoo made with nutritive organic apple cider vinegar & r ... (926 characters truncated) ... oughly remove product buildup and repair damaged follicles without stripping hair of moisture. Soothe scalp and renew hair for healthy beautiful hair', 22)
# ('Papad - Garlic Disco', 'Snacks & Branded Foods', 'Ready To Cook & Eat', 'Atish ', 61.0, 61.0, 'Papads, Ready To Fry', 4.0, 'Papads are prepared from urad dal flour and spiced with taste. They are supplied roasted on an open flame, which creates them fluffy and crunchy appetizers.', 21)
# ('Wottagirl! Perfume Spray - Heaven, Classic', 'Beauty & Hygiene', 'Fragrances & Deos', 'Layerr', 199.2, 249.0, 'Perfume', 3.9, 'Layerr brings you Wottagirl Classic fragrant body splashes. For the confident, smart, genuine woman who doesnt get caught up in fads, diets and all things nonsense; comes a range of pure, exquisite fragrances that are just as pure, beautiful, resilient and bold.', 24)
# ('Rosemary', 'Gourmet & World Food', 'Cooking & Baking Needs', 'Puramate', 67.5, 75.0, 'Herbs, Seasonings & Rubs', 4.0, 'Puramate rosemary is enough to transform a dish into something\r\nextraordinary. It is vibrant , dynamic ,aromatic and a perfect flavor booster.\r\nS ... (145 characters truncated) ... eas and\r\nseasoning blends and they can lend that instant zing. Pairs well with bay, garlic,\r\nmarjoram, oregano, parsley, sage, savory, and thyme.', 24)
# ('Peri-Peri Sweet Potato Chips', 'Gourmet & World Food', 'Snacks, Dry Fruits, Nuts', 'FabBox', 200.0, 200.0, 'Nachos & Chips', 3.8, 'We have taken the richness of Sweet Potatoes (Shakarkand) and given it a spicy delicious Peri Peri twist! The crispiness is unlike anything before an ... (173 characters truncated) ... n-fried, which means they have almost 82% less oil than standard market chips. So yes, you can be on a diet and still relish chips like never before!', 16)
# ('Green Tea - Pure Original', 'Beverages', 'Tea', 'Tetley', 396.0, 495.0, 'Tea Bags', 4.2, 'Tetley Green Tea with its refreshing pure, original flavour contains five times more antioxidants than fruits and vegetables. A cup of Tetley Natural ... (54 characters truncated) ... l those pollutants and toxins that our bodies are exposed to on a daily basis!! Rejuvenate yourself every day with a cup of Tetley Natural Green Tea.', 14)
# ('United Dreams Go Far Deodorant', 'Beauty & Hygiene', "Men's Grooming", 'United Colors Of Benetton ', 214.53, 390.0, "Men's Deodorants", 4.5, 'The new mens fragrance from the United Dreams collection is dedicated to any man who loves setting his sights high. This cologne with frizzy hints of ... (122 characters truncated) ... it and lemon combine with aromatic mint, nutmeg, sage and geranium. A mix that is intensified by exotic dashes of patchouli, vetiver, musk and amber.', 29)

# %% [markdown]
# ### Define SQL Database
#
# We first define our `SQLDatabase` abstraction (a light wrapper around SQLAlchemy).

# %%
from llama_index.core import SQLDatabase
from google.colab import userdata
GROQ_API_KEY = "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"

# %%
sql_database = SQLDatabase(engine, include_tables=["products"])

# %% [markdown]
# We add some testing data to our SQL database.

# %% [markdown]
# ### Query Index

# %% [markdown]
# We first show how we can execute a raw SQL query, which directly executes over the table.

# %%
llm = Groq(model="llama3-70b-8192", api_key=GROQ_API_KEY)

# %%
embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Part 1: Text-to-SQL Query Engine
# Once we have constructed our SQL database, we can use the NLSQLTableQueryEngine to
# construct natural language queries that are synthesized into SQL queries.
#
# Note that we need to specify the tables we want to use with this query engine.
# If we don't the query engine will pull all the schema context, which could
# overflow the context window of the LLM.

# %%
from llama_index.core.query_engine import NLSQLTableQueryEngine

query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database, tables=["products"], llm=llm, embed_model=embed_model
)
query_str = "Tell me about Nivea products"
response = query_engine.query(query_str)

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Nivea offers a wide range of products in the beauty and hygiene category, with a total of 64 products in their lineup. These products have an average rating of 4.2 out of 5 stars, indicating high customer satisfaction.
#
# The top-rated products from Nivea include the Sensitive Cooling Shaving Gel with a perfect 5-star rating, followed closely by the Whitening Talc Touch Deodorant and the Creme Care Soap for Hands and Body, both with a 4.7-star rating.
#
# Nivea's product range covers a variety of categories, including soaps, body lotions, deodorants, face washes, and lip balms. They offer products suitable for different skin types, including sensitive skin, dry skin, and oily skin.
#
# Some popular products from Nivea include the Soft Aloe Moisturising Cream, the Whitening Smooth Skin Women Deodorant, and the Milk Delights Face Wash with Turmeric for Acne Prone Skin.
#
# Overall, Nivea's products are known for their high quality and effectiveness, making them a popular choice among consumers.</b>

# %% [markdown]
# This query engine should be used in any case where you can specify the tables you want
# to query over beforehand, or the total size of all the table schema plus the rest of
# the prompt fits your context window.

# %% [markdown]
# You can also add additional context information for each table schema you define.
